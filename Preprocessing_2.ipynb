# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Crop_yield1.csv')
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area   Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0      56708.0
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0       4685.0
# 2   Castor seed       1997  Kharif       Assam    796.0         22.0
# 3      Coconut        1997  Whole Year   Assam  19656.0  126905000.0
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0        794.0
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
south_indian_states={'Kerala','Tamil Nadu','Karnataka','Andhra Pradesh','Telangana','Puducherry'}
df2=df[df['State'].isin(south_indian_states)]
df2.head()
# Out:
#             Crop  Crop_Year       Season      State      Area  Production  \
# 27      Arecanut       1997  Whole Year   Karnataka   93100.0    133342.0
# 28     Arhar/Tur       1997  Kharif       Karnataka  421810.0     98473.0
# 29         Bajra       1997  Kharif       Karnataka  301149.0    132056.0
# 30         Bajra       1997  Summer       Karnataka     820.0       662.0
# 31  Black pepper       1997  Kharif       Karnataka    3825.0       924.0
#
#     Annual_Rainfall   Fertilizer  Pesticide     Yield
# 27           1266.7   8860327.00   28861.00  1.293571
# 28           1266.7  40143657.70  130761.10  0.268235
# 29           1266.7  28660350.33   93356.19  0.404545
# 30           1266.7     78039.40     254.20  0.810000
# 31           1266.7    364025.25    1185.75  0.437500

# %%
df2.shape
# Out:
# (5115, 10)

# %%
df2.describe()
# Out:
#          Crop_Year          Area    Production  Annual_Rainfall    Fertilizer  \
# count  5067.000000  5.067000e+03  5.067000e+03      5067.000000  5.067000e+03
# mean   2009.796921  1.348188e+05  5.885957e+07      1265.993415  1.807077e+07
# std       6.470713  3.070120e+05  5.154328e+08       604.119858  4.193271e+07
# min    1997.000000  1.000000e+00  0.000000e+00       315.900000  9.817000e+01
# 25%    2004.000000  1.589500e+03  1.948000e+03       926.500000  2.285093e+05
# 50%    2011.000000  1.778900e+04  2.538700e+04      1111.700000  2.481263e+06
# 75%    2015.000000  1.127835e+05  1.988395e+05      1348.700000  1.536361e+07
# max    2019.000000  3.003673e+06  6.326000e+09      3489.600000  4.853390e+08
#
#            Pesticide         Yield
# count    5067.000000   5067.000000
# mean    36305.685338    194.654345
# std     85309.882663   1399.640139
# min         0.090000      0.000000
# 25%       444.675000      0.590851
# 50%      4611.360000      1.328750
# 75%     30181.800000      3.503155
# max    948403.170000  21105.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5067 entries, 0 to 5114
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             5067 non-null   object
#  1   Crop_Year        5067 non-null   int64
#  2   Season           5067 non-null   object
#  3   State            5067 non-null   object
#  4   Area             5067 non-null   float64
#  5   Production       5067 non-null   float64
#  6   Annual_Rainfall  5067 non-null   float64
#  7   Fertilizer       5067 non-null   float64
#  8   Pesticide        5067 non-null   float64
#  9   Yield            5067 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 435.4+ KB

# %%
df2.reset_index(drop=True, inplace=True)
df2.head()
# Out:
#            Crop  Crop_Year       Season      State      Area  Production  \
# 0      Arecanut       1997  Whole Year   Karnataka   93100.0    133342.0
# 1     Arhar/Tur       1997  Kharif       Karnataka  421810.0     98473.0
# 2         Bajra       1997  Kharif       Karnataka  301149.0    132056.0
# 3         Bajra       1997  Summer       Karnataka     820.0       662.0
# 4  Black pepper       1997  Kharif       Karnataka    3825.0       924.0
#
#    Annual_Rainfall   Fertilizer  Pesticide     Yield
# 0           1266.7   8860327.00   28861.00  1.293571
# 1           1266.7  40143657.70  130761.10  0.268235
# 2           1266.7  28660350.33   93356.19  0.404545
# 3           1266.7     78039.40     254.20  0.810000
# 4           1266.7    364025.25    1185.75  0.437500

# %%
df2['Season'].unique()
# Out:
# array(['Whole Year ', 'Kharif     ', 'Summer     ', 'Rabi       ',
#        'Autumn     ', 'Winter     '], dtype=object)

# %%
df2['Crop'].unique()
# Out:
# array(['Arecanut', 'Arhar/Tur', 'Bajra', 'Black pepper', 'Cardamom',
#        'Coriander', 'Dry chillies', 'Garlic', 'Ginger', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Maize', 'Ragi', 'Rice', 'Sugarcane',
#        'Turmeric', 'Wheat', 'Cashewnut', 'Coconut ', 'Tapioca',
#        'Cotton(lint)', 'Onion', 'Sesamum', 'Small millets', 'Castor seed',
#        'Gram', 'Linseed', 'Moong(Green Gram)', 'Niger seed',
#        'Peas & beans (Pulses)', 'Potato', 'Rapeseed &Mustard',
#        'Safflower', 'Sunflower', 'Banana', 'Sweet potato', 'Tobacco',
#        'Other  Rabi pulses', 'Urad', 'Mesta', 'Other Kharif pulses',
#        'Sannhamp', 'Soyabean', 'other oilseeds', 'Other Cereals',
#        'Cowpea(Lobia)', 'Jute', 'Masoor', 'Oilseeds total', 'Guar seed',
#        'Other Summer Pulses'], dtype=object)

# %%
df2['State'].unique()
# Out:
# array(['Karnataka', 'Kerala', 'Puducherry', 'Andhra Pradesh',
#        'Tamil Nadu', 'Telangana'], dtype=object)

# %%
df2.isna().sum()
# Out:
# Crop                0
# Crop_Year           0
# Season              0
# State               0
# Area                0
# Production         33
# Annual_Rainfall     6
# Fertilizer          0
# Pesticide           0
# Yield              48
# dtype: int64

# %% [markdown]
# #**Data Preprocessing**
#
# *   Null Value Handling

# %%
# Remove trailing spaces from all string values in the Data
df2 = df2.apply(lambda x: x.str.rstrip() if x.dtype == "object" else x)

# %%
#checking for distribution
states=df2['State'].unique()

# Create a dictionary to store the data for each state
rainfall_data = {}

# Loop through each state and filter the data
for state in states:
    rainfall_data[state] = df2[df2['State'] == state]['Annual_Rainfall']

# Create subplots
fig, axes = plt.subplots(nrows=1, ncols=len(states), figsize=(18, 6), sharey=True)

# Plot histograms for each state's data
for ax, state in zip(axes, states):
    sns.histplot(rainfall_data[state], kde=True, bins=25, ax=ax)
    ax.set_title(f'Annual Rainfall Distribution in {state}')
    ax.set_xlabel('Annual Rainfall (mm)')
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Filter the dataframe for rows where Annual_Rainfall is null
null_rainfall = df[df['Annual_Rainfall'].isnull()]

# Select the columns Crop_Year, State, and Season
null_rainfall_info = null_rainfall[['Crop_Year', 'State', 'Season']]

# Print the filtered information
print(null_rainfall_info)
# Out:
#       Crop_Year           State       Season
# 55         1997       Karnataka  Whole Year
# 56         1997       Karnataka  Rabi
# 190        1998       Karnataka  Rabi
# 191        1998       Karnataka  Summer
# 1035       2002  Andhra Pradesh  Rabi
# 1036       2002  Andhra Pradesh  Rabi

# %%
#Filling the null values using the forward filling method
df2.loc[:,'Annual_Rainfall']=df2['Annual_Rainfall'].ffill()

# %%
#Checking for null values in all the columns
df2.isnull().sum()
# Out:
# Crop                0
# Crop_Year           0
# Season              0
# State               0
# Area                0
# Production         33
# Annual_Rainfall     0
# Fertilizer          0
# Pesticide           0
# Yield              48
# dtype: int64

# %%
#Jute Production in Tamilnadu
df3=df2[df2['Crop']=='Jute']
df3
# Out:
#       Crop  Crop_Year  Season       State  Area  Production  Annual_Rainfall  \
# 2197  Jute       2011  Kharif  Tamil Nadu   3.0         0.0            926.5
#
#       Fertilizer  Pesticide  Yield
# 2197      502.56       0.99    NaN

# %% [markdown]
# Jute entry in the dataset is only at one place.And also the noted Yield value is also Null. Drop the entry is preferable here.

# %%
# Drop Jute Entry
df2= df2.drop(df2[df2['Crop'] == 'Jute'].index)
df2['Crop'].unique()
# Out:
# array(['Arecanut', 'Arhar/Tur', 'Bajra', 'Black pepper', 'Cardamom',
#        'Coriander', 'Dry chillies', 'Garlic', 'Ginger', 'Groundnut',
#        'Horse-gram', 'Jowar', 'Maize', 'Ragi', 'Rice', 'Sugarcane',
#        'Turmeric', 'Wheat', 'Cashewnut', 'Coconut', 'Tapioca',
#        'Cotton(lint)', 'Onion', 'Sesamum', 'Small millets', 'Castor seed',
#        'Gram', 'Linseed', 'Moong(Green Gram)', 'Niger seed',
#        'Peas & beans (Pulses)', 'Potato', 'Rapeseed &Mustard',
#        'Safflower', 'Sunflower', 'Banana', 'Sweet potato', 'Tobacco',
#        'Other  Rabi pulses', 'Urad', 'Mesta', 'Other Kharif pulses',
#        'Sannhamp', 'Soyabean', 'other oilseeds', 'Other Cereals',
#        'Cowpea(Lobia)', 'Masoor', 'Oilseeds total', 'Guar seed',
#        'Other Summer Pulses'], dtype=object)

# %%
#Cashewnut production in Tamilnadu
df3=df2[(df2['State']=='Tamil Nadu') & (df2['Crop']=='Cashewnut')&((df2['Annual_Rainfall'] >= 900) & (df2['Annual_Rainfall'] <= 1000))&(df2['Season']=='Whole Year')&((df2['Area'] > 80000) & (df2['Area'] <90000))]
df3
# Out:
#            Crop  Crop_Year      Season       State     Area  Production  \
# 2760  Cashewnut       2014  Whole Year  Tamil Nadu  89021.0     36561.0
# 3262  Cashewnut       2016  Whole Year  Tamil Nadu  86280.0     10178.0
# 3521  Cashewnut       2017  Whole Year  Tamil Nadu  85883.0         NaN
# 3784  Cashewnut       2018  Whole Year  Tamil Nadu  85272.0     19701.0
# 4051  Cashewnut       2019  Whole Year  Tamil Nadu  83977.0     25687.0
# 4300  Cashewnut       2000  Whole Year  Tamil Nadu  88123.0     20348.0
#
#       Annual_Rainfall   Fertilizer  Pesticide     Yield
# 2760            911.3  13438610.16   29376.93  0.468571
# 3262            912.4  13222410.00   30198.00  0.168571
# 3521            970.9  13521419.52   32635.54       NaN
# 3784            986.2  13831118.40   29845.20  0.242000
# 4051            910.1  14423889.52   31071.49  0.335172
# 4300            971.1   8651034.91   22911.98  0.304783

# %%
#Applied Backward Filling
df3.loc[:,'Production'] = df3['Production'].bfill()
df2.update(df3)

# %%
#Maize Production in Tamilnadu
df3=df2[(df2['State']=='Tamil Nadu') & (df2['Crop']=='Maize')&(df2['Annual_Rainfall']>=1000)&(df2['Season']=='Kharif')]
df3
# Out:
#        Crop  Crop_Year  Season       State      Area  Production  \
# 853   Maize       2004  Kharif  Tamil Nadu  189893.0    294717.0
# 1029  Maize       2005  Kharif  Tamil Nadu  202830.0         0.0
# 3022  Maize       2015  Kharif  Tamil Nadu  201750.0   1483163.0
# 4188  Maize       1998  Kharif  Tamil Nadu   70179.0    111983.0
# 4496  Maize       2010  Kharif  Tamil Nadu  230489.0   1027536.0
#
#       Annual_Rainfall   Fertilizer  Pesticide     Yield
# 853            1034.0  20573007.62   39877.53  1.758846
# 1029           1364.1  24323373.60   42594.30       NaN
# 3022           1201.9  31858342.50   66577.50  7.782000
# 4188           1077.1   6933685.20   20351.91  1.606667
# 4496           1095.2  38286527.79   55317.36  4.527857

# %%
df3.loc[df3['Production'] == 0, 'Production'] =pd.NA
df3.loc[:,'Production'] = df3['Production'].bfill()
# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Arecanut Production in Tamilnadu
df3=df2[(df2['State']=='Tamil Nadu') & (df2['Crop']=='Arecanut')]
df3
# Out:
#           Crop  Crop_Year      Season       State    Area  Production  \
# 538   Arecanut       2002  Whole Year  Tamil Nadu  4956.0         0.0
# 723   Arecanut       2003  Whole Year  Tamil Nadu  5219.0         0.0
# 836   Arecanut       2004  Whole Year  Tamil Nadu  5077.0      7390.0
# 1011  Arecanut       2005  Whole Year  Tamil Nadu  4773.0      9198.0
# 1201  Arecanut       2006  Whole Year  Tamil Nadu  5526.0     11904.0
# 1357  Arecanut       2007  Whole Year  Tamil Nadu  5553.0     11739.0
# 1569  Arecanut       2008  Whole Year  Tamil Nadu  5612.0     11061.0
# 1784  Arecanut       2009  Whole Year  Tamil Nadu  5456.0     10437.0
# 2175  Arecanut       2011  Whole Year  Tamil Nadu  6509.0     15948.0
# 2541  Arecanut       2013  Whole Year  Tamil Nadu  6695.0      8619.0
# 2754  Arecanut       2014  Whole Year  Tamil Nadu  6732.0      8837.0
# 3000  Arecanut       2015  Whole Year  Tamil Nadu  6884.0     11829.0
# 3255  Arecanut       2016  Whole Year  Tamil Nadu  7078.0     12708.0
# 3514  Arecanut       2017  Whole Year  Tamil Nadu  6740.0     14926.0
# 3777  Arecanut       2018  Whole Year  Tamil Nadu  6952.0     13543.0
# 4043  Arecanut       2019  Whole Year  Tamil Nadu  6843.0     13543.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 538             315.9   469184.52    1239.00  0.000000
# 723             345.6   516576.62    1252.56       NaN
# 836            1034.0   550042.18    1066.17  1.550000
# 1011           1364.1   572378.16    1002.33  1.212727
# 1201            927.9   705725.46    1215.72  1.603636
# 1357           1067.2   740770.20     888.48  2.057391
# 1569           1201.9   802740.48     505.08  1.708333
# 1784            928.5   850153.92     927.52  1.605000
# 2175            926.5  1090387.68    2147.97  2.054583
# 2541            740.9   967360.55    1807.65  1.220000
# 2754            911.3  1016262.72    2221.56  1.561905
# 3000           1201.9  1087052.44    2271.72  1.597143
# 3255            912.4  1084703.50    2477.30  1.477273
# 3514            970.9  1061145.60    2561.20  2.313043
# 3777            986.2  1127614.40    2433.20  2.011200
# 4043            910.1  1175353.68    2531.91  2.170000

# %%
df3.loc[df3['Production'] == 0, 'Production'] =pd.NA
df3.loc[:,'Production'] = df3['Production'].bfill()

# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Sweet potato production in Puducherry
df3=df2[(df2['State']=='Puducherry') & (df2['Crop']=='Sweet potato')]
df3.loc[df3['Production'] == 0, 'Production'] =pd.NA
df3
# Out:
#               Crop  Crop_Year  Season       State  Area  Production  \
# 1264  Sweet potato       2007    Rabi  Puducherry   1.0         1.0
# 1424  Sweet potato       2008    Rabi  Puducherry   1.0         1.0
# 1636  Sweet potato       2009  Kharif  Puducherry   1.0         NaN
# 1850  Sweet potato       2010  Kharif  Puducherry   1.0         8.0
# 2893  Sweet potato       2015  Kharif  Puducherry   5.0        73.0
# 2894  Sweet potato       2015    Rabi  Puducherry   3.0        34.0
# 3150  Sweet potato       2016  Kharif  Puducherry   6.0        60.0
# 3408  Sweet potato       2017  Kharif  Puducherry   7.0        35.0
# 3409  Sweet potato       2017    Rabi  Puducherry   1.0         8.0
# 3673  Sweet potato       2018  Kharif  Puducherry   3.0        24.0
# 3936  Sweet potato       2019  Kharif  Puducherry   5.0        45.0
# 3937  Sweet potato       2019    Rabi  Puducherry   1.0         9.0
# 4995  Sweet potato       2012  Kharif  Puducherry   2.0        24.0
# 4996  Sweet potato       2012    Rabi  Puducherry   2.0        18.0
# 5034  Sweet potato       2013  Kharif  Puducherry   1.0         9.0
# 5035  Sweet potato       2013    Rabi  Puducherry   1.0        10.0
# 5070  Sweet potato       2014  Kharif  Puducherry   4.0        60.0
# 5071  Sweet potato       2014    Rabi  Puducherry   2.0        23.0
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 1264        1434.5875      133.40       0.16   1.00
# 1424        1434.5875      143.04       0.09   1.00
# 1636        1434.5875      155.82       0.17   0.00
# 1850        1434.5875      166.11       0.24   8.00
# 2893        1980.6000      789.55       1.65  14.60
# 2894        1980.6000      473.73       0.99  11.33
# 3150        1391.3000      919.50       2.10  10.00
# 3408        1582.4000     1102.08       2.66   5.00
# 3409        1582.4000      157.44       0.38   8.00
# 3673        1693.9000      486.60       1.05   8.00
# 3936        1317.0000      858.80       1.85   9.00
# 3937        1317.0000      171.76       0.37   9.00
# 4995        1098.3000      301.60       0.62  12.00
# 4996        1098.3000      301.60       0.62   9.00
# 5034        1083.2000      144.49       0.27   9.00
# 5035        1083.2000      144.49       0.27  10.00
# 5070        1330.0000      603.84       1.32  15.00
# 5071        1330.0000      301.92       0.66  11.50

# %%
#Applied Forward filling by consider the facters Area,rainfall fertilizer and pesticide
df3.loc[:,'Production'] = df3['Production'].ffill()

# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Turmeric Production in Puducherry
df3=df2[(df2['State']=='Puducherry') & (df2['Crop']=='Turmeric')]
df3.loc[df3['Production'] == 0, 'Production'] =pd.NA
df3
# Out:
#           Crop  Crop_Year  Season       State  Area  Production  \
# 1267  Turmeric       2007    Rabi  Puducherry   4.0         6.0
# 1427  Turmeric       2008    Rabi  Puducherry   3.0         5.0
# 1639  Turmeric       2009  Kharif  Puducherry   3.0         NaN
# 1640  Turmeric       2009    Rabi  Puducherry   3.0         5.0
# 1853  Turmeric       2010  Kharif  Puducherry   4.0         6.0
# 2026  Turmeric       2011  Kharif  Puducherry   2.0         3.0
# 2027  Turmeric       2011    Rabi  Puducherry   4.0         6.0
# 2897  Turmeric       2015  Kharif  Puducherry   2.0         4.0
# 3153  Turmeric       2016  Kharif  Puducherry   6.0        18.0
# 3412  Turmeric       2017  Kharif  Puducherry   8.0        24.0
# 3676  Turmeric       2018  Kharif  Puducherry   6.0        15.0
# 3940  Turmeric       2019  Kharif  Puducherry  11.0       165.0
# 4999  Turmeric       2012    Rabi  Puducherry   5.0         9.0
# 5038  Turmeric       2013    Rabi  Puducherry   2.0         5.0
# 5074  Turmeric       2014    Rabi  Puducherry   1.0         2.0
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 1267        1434.5875      533.60       0.64   1.50
# 1427        1434.5875      429.12       0.27   1.67
# 1639        1434.5875      467.46       0.51   0.00
# 1640        1434.5875      467.46       0.51   1.67
# 1853        1434.5875      664.44       0.96   1.50
# 2026        1434.5875      335.04       0.66   1.50
# 2027        1434.5875      670.08       1.32   1.50
# 2897        1980.6000      315.82       0.66   2.00
# 3153        1391.3000      919.50       2.10   3.00
# 3412        1582.4000     1259.52       3.04   3.00
# 3676        1693.9000      973.20       2.10   2.50
# 3940        1317.0000     1889.36       4.07  15.00
# 4999        1098.3000      754.00       1.55   1.80
# 5038        1083.2000      288.98       0.54   2.50
# 5074        1330.0000      150.96       0.33   2.00

# %%
#Applied Forward filling by consider the facters Area,rainfall fertilizer and pesticide
df3.loc[:,'Production'] = df3['Production'].ffill()

# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Horse gram in Telengana
df3=df2[(df2['State']=='Telangana') & (df2['Crop']=='Horse-gram')&(df2['Season']=='Kharif')]
df3
# Out:
#             Crop  Crop_Year  Season      State   Area  Production  \
# 4539  Horse-gram       2013  Kharif  Telangana  507.0       315.0
# 4597  Horse-gram       2014  Kharif  Telangana  529.0       274.0
# 4659  Horse-gram       2015  Kharif  Telangana  510.0       110.0
# 4718  Horse-gram       2016  Kharif  Telangana  353.0       135.0
# 4774  Horse-gram       2017  Kharif  Telangana  237.0         NaN
# 4827  Horse-gram       2018  Kharif  Telangana  144.0        92.0
# 4880  Horse-gram       2019  Kharif  Telangana  431.0       371.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4539           1348.7    73256.43     136.89  0.610000
# 4597            746.4    79857.84     174.57  0.510000
# 4659            747.9    80534.10     168.30  0.220000
# 4718            942.6    54097.25     123.55  0.395714
# 4774            815.7    37313.28      90.06       NaN
# 4827           1350.3    23356.80      50.40  0.654000
# 4880           1031.7    74028.56     159.47  0.818333

# %%
#Applied Forward filling by consider the facters Area,rainfall fertilizer and pesticide
df3.loc[:,'Production'] = df3['Production'].bfill()
# Apply df3 modifications back to df2
df2.update(df3)

# %%
df3=df2[(df2['State']=='Telangana') & (df2['Crop']=='Horse-gram')&(df2['Season']=='Rabi')]
df3
# Out:
#             Crop  Crop_Year Season      State    Area  Production  \
# 4540  Horse-gram       2013   Rabi  Telangana  2437.0      1165.0
# 4598  Horse-gram       2014   Rabi  Telangana  1778.0       679.0
# 4660  Horse-gram       2015   Rabi  Telangana  1530.0       684.0
# 4719  Horse-gram       2016   Rabi  Telangana  1310.0       500.0
# 4775  Horse-gram       2017   Rabi  Telangana   963.0         NaN
# 4828  Horse-gram       2018   Rabi  Telangana   736.0       467.0
# 4881  Horse-gram       2019   Rabi  Telangana   619.0       539.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4540           1348.7   352122.13     657.99  0.481429
# 4598            746.4   268406.88     586.74  0.393750
# 4660            747.9   241602.30     504.90  0.418889
# 4719            942.6   200757.50     458.50  0.360625
# 4775            815.7   151614.72     365.94       NaN
# 4828           1350.3   119379.20     257.60  0.668571
# 4881           1031.7   106319.44     229.03  0.870526

# %%
#Applied Forward filling by consider the facters Area,rainfall fertilizer and pesticide
df3.loc[:,'Production'] = df3['Production'].bfill()
# Apply df3 modifications back to df2
df2.update(df3)

# %%
df3=df2[(df2['State']=='Telangana') & (df2['Crop']=='Potato')&(df2['Season']=='Kharif')]
df3
# Out:
#         Crop  Crop_Year  Season      State  Area  Production  Annual_Rainfall  \
# 4613  Potato       2014  Kharif  Telangana   9.0       173.0            746.4
# 4728  Potato       2016  Kharif  Telangana  37.0       405.0            942.6
# 4784  Potato       2017  Kharif  Telangana  19.0       163.0            815.7
# 4837  Potato       2018  Kharif  Telangana   8.0        24.0           1350.3
# 4890  Potato       2019  Kharif  Telangana   3.0         NaN           1031.7
#
#       Fertilizer  Pesticide   Yield
# 4613     1358.64       2.97  19.220
# 4728     5670.25      12.95  10.795
# 4784     2991.36       7.22   7.940
# 4837     1297.60       2.80   3.000
# 4890      515.28       1.11     NaN

# %% [markdown]
# consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =area*3

# %%
#consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =area*3
df3.loc[:,'Production'] = df3['Production'].fillna(9)
# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Safflower Production Telangana
df3=df2[(df2['State']=='Telangana') & (df2['Crop']=='Safflower')]
df3
# Out:
#            Crop  Crop_Year  Season      State    Area  Production  \
# 4561  Safflower       2013    Rabi  Telangana  7867.0      5573.0
# 4620  Safflower       2014    Rabi  Telangana  4155.0      3100.0
# 4679  Safflower       2015    Rabi  Telangana  3855.0      2581.0
# 4734  Safflower       2016  Kharif  Telangana     5.0         5.0
# 4735  Safflower       2016    Rabi  Telangana  4364.0      2892.0
# 4790  Safflower       2017    Rabi  Telangana  3862.0      2189.0
# 4843  Safflower       2018    Rabi  Telangana  2552.0      1543.0
# 4896  Safflower       2019  Kharif  Telangana     1.0         NaN
# 4897  Safflower       2019    Rabi  Telangana  1584.0      1750.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4561           1348.7  1136702.83    2124.09  0.750000
# 4620            746.4   627238.80    1371.15  0.752000
# 4679            747.9   608743.05    1272.15  0.806000
# 4734            942.6      766.25       1.75  1.000000
# 4735            942.6   668783.00    1527.40  0.731111
# 4790            815.7   608033.28    1467.56  0.606250
# 4843           1350.3   413934.40     893.20  0.749000
# 4896           1031.7      171.76       0.37       NaN
# 4897           1031.7   272067.84     586.08  1.106364

# %% [markdown]
# consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =1

# %%
#consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =1
df3.loc[:,'Production'] = df3['Production'].fillna(1)
# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Wheat Production Telangana
df3=df2[(df2['State']=='Telangana') & (df2['Crop']=='Wheat')]
df3
# Out:
#        Crop  Crop_Year  Season      State    Area  Production  \
# 4576  Wheat       2013    Rabi  Telangana  7039.0      4366.0
# 4636  Wheat       2014    Rabi  Telangana  5828.0      6929.0
# 4695  Wheat       2015    Rabi  Telangana  4952.0     16902.0
# 4752  Wheat       2016    Rabi  Telangana  5409.0      7413.0
# 4804  Wheat       2017  Kharif  Telangana     2.0         2.0
# 4805  Wheat       2017    Rabi  Telangana  4156.0      5771.0
# 4859  Wheat       2018    Rabi  Telangana  4844.0      9093.0
# 4913  Wheat       2019  Kharif  Telangana     1.0         NaN
# 4914  Wheat       2019    Rabi  Telangana  4471.0      8237.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4576           1348.7  1017065.11    1900.53  0.740000
# 4636            746.4   879794.88    1923.24  1.156000
# 4695            747.9   781970.32    1634.16  2.947500
# 4752            942.6   828929.25    1893.15  1.223571
# 4804            815.7      314.88       0.76  1.000000
# 4805            815.7   654320.64    1579.28  1.429000
# 4859           1350.3   785696.80    1695.40  1.807000
# 4913           1031.7      171.76       0.37       NaN
# 4914           1031.7   767938.96    1654.27  1.798462

# %% [markdown]
# consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =1

# %%
#consider Area ,rainfall, fertilizer and pesticide used in previous year in the Kharif season set production =1
df3.loc[:,'Production'] = df3['Production'].fillna(1)
# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Mesta Production in Karnataka
df3=df2[(df2['State']=='Karnataka') & (df2['Crop']=='Mesta')&(df2['Season']=='Whole Year')]
df3
# Out:
#        Crop  Crop_Year      Season      State    Area  Production  \
# 951   Mesta       2005  Whole Year  Karnataka  2097.0      2662.0
# 1148  Mesta       2006  Whole Year  Karnataka  1998.0      2667.0
# 1300  Mesta       2007  Whole Year  Karnataka  1861.0      2387.0
# 1513  Mesta       2008  Whole Year  Karnataka  1146.0      1617.0
# 1727  Mesta       2009  Whole Year  Karnataka  1300.0      1885.0
# 1943  Mesta       2010  Whole Year  Karnataka  1907.0      2405.0
# 2121  Mesta       2011  Whole Year  Karnataka   825.0      1028.0
# 2309  Mesta       2012  Whole Year  Karnataka   713.0       871.0
# 2476  Mesta       2013  Whole Year  Karnataka   349.0       466.0
# 2688  Mesta       2014  Whole Year  Karnataka   261.0       293.0
# 2935  Mesta       2015  Whole Year  Karnataka   766.0      1024.0
# 3190  Mesta       2016  Whole Year  Karnataka   105.0       107.0
# 3449  Mesta       2017  Whole Year  Karnataka     9.0         NaN
# 3711  Mesta       2018  Whole Year  Karnataka    81.0       116.0
# 3975  Mesta       2019  Whole Year  Karnataka    55.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 951       1316.200000   251472.24     440.37  1.568000
# 1148      1146.300000   255164.58     439.56  1.543333
# 1300      1323.300000   248257.40     297.76  1.554000
# 1513      1164.100000   163923.84     103.14  1.636000
# 1727      1321.000000   202566.00     221.00  1.324000
# 1943      1317.700000   316771.77     457.68  1.210000
# 2121      1178.986364   138204.00     272.25  1.202857
# 2309       956.200000   107520.40     221.03  1.242000
# 2476      1235.600000    50427.01      94.23  1.330000
# 2688      1238.500000    39400.56      86.13  1.123333
# 2935      1024.900000   120959.06     252.78  1.335000
# 3190      1147.200000    16091.25      36.75  1.040000
# 3449      1111.700000     1416.96       3.42       NaN
# 3711      1419.100000    13138.20      28.35  1.334545
# 3975      1422.300000     9446.80      20.35       NaN

# %%
#By Analising the data find that production is approximatly 125% of Area and Filled the Null values in production accordingly
df3=df3[df3['Production'].isnull()]
df3
# Out:
#        Crop  Crop_Year      Season      State  Area  Production  \
# 3449  Mesta       2017  Whole Year  Karnataka   9.0         NaN
# 3975  Mesta       2019  Whole Year  Karnataka  55.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 3449           1111.7     1416.96       3.42    NaN
# 3975           1422.3     9446.80      20.35    NaN

# %%
df3.loc[:,'Production'] = df3['Production'].fillna(df3['Area']*1.25)
# Apply df3 modifications back to df2
df2.update(df3)

# %%
#Kerala (Onion,Horse gram,Moong, Urad,Cowpea)Production
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Onion')]
df3
# Out:
#        Crop  Crop_Year      Season   State    Area  Production  \
# 2359  Onion       2012  Whole Year  Kerala   40.00         0.0
# 2526  Onion       2013  Whole Year  Kerala  103.00         NaN
# 2738  Onion       2014  Whole Year  Kerala   61.00         NaN
# 2984  Onion       2015  Whole Year  Kerala   27.00         NaN
# 3240  Onion       2016  Whole Year  Kerala   31.00         NaN
# 3499  Onion       2017  Whole Year  Kerala    9.00         NaN
# 3762  Onion       2018  Whole Year  Kerala    5.21         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2359           2187.6    6032.000    12.4000    NaN
# 2526           3255.4   14882.470    27.8100    NaN
# 2738           3046.4    9208.560    20.1300    NaN
# 2984           2602.9    4263.570     8.9100    NaN
# 3240           2924.3    4750.750    10.8500    NaN
# 3499           2664.8    1416.960     3.4200    NaN
# 3762           2989.7     845.062     1.8235    NaN

# %%
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Cowpea(Lobia)')]
df3
# Out:
#                Crop  Crop_Year      Season   State    Area  Production  \
# 2351  Cowpea(Lobia)       2012  Whole Year  Kerala  1085.0         0.0
# 2518  Cowpea(Lobia)       2013  Whole Year  Kerala   775.0         NaN
# 2730  Cowpea(Lobia)       2014  Whole Year  Kerala  1004.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2351           2187.6   163618.00     336.35    NaN
# 2518           3255.4   111979.75     209.25    NaN
# 2730           3046.4   151563.84     331.32    NaN

# %%
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Horse-gram')]
df3
# Out:
#             Crop  Crop_Year      Season   State   Area  Production  \
# 2355  Horse-gram       2012  Whole Year  Kerala  105.0         0.0
# 2522  Horse-gram       2013  Whole Year  Kerala   69.0         NaN
# 2734  Horse-gram       2014  Whole Year  Kerala  111.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2355           2187.6    15834.00      32.55    NaN
# 2522           3255.4     9969.81      18.63    NaN
# 2734           3046.4    16756.56      36.63    NaN

# %%
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Moong(Green Gram)')]
df3
# Out:
#                    Crop  Crop_Year      Season   State   Area  Production  \
# 2358  Moong(Green Gram)       2012  Whole Year  Kerala  101.0         0.0
# 2525  Moong(Green Gram)       2013  Whole Year  Kerala  121.0         NaN
# 2737  Moong(Green Gram)       2014  Whole Year  Kerala  163.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2358           2187.6    15230.80      31.31    NaN
# 2525           3255.4    17483.29      32.67    NaN
# 2737           3046.4    24606.48      53.79    NaN

# %%
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Urad')]
df3
# Out:
#       Crop  Crop_Year      Season   State   Area  Production  Annual_Rainfall  \
# 2374  Urad       2012  Whole Year  Kerala  265.0         0.0           2187.6
# 2540  Urad       2013  Whole Year  Kerala  374.0         NaN           3255.4
# 2752  Urad       2014  Whole Year  Kerala  403.0         NaN           3046.4
#
#       Fertilizer  Pesticide  Yield
# 2374    39962.00      82.15    NaN
# 2540    54039.26     100.98    NaN
# 2752    60836.88     132.99    NaN

# %%
df3=df2[df2['State']=='Kerala']
df3=df3['Production'].fillna(0)
# Apply df3 modifications back to df2
df2.update(df3)

# %% [markdown]
# As the data of the Onion production in kerala is noted as 0 in the 2012 significant production is not happening at kerala.Therefore we filled it with 0 in all columns. The yield value is also null.Same trend is visible in the cases of Cowpea,Horse gram,Moong and Urad. filled it with 0 in all the cases.

# %%
#Wheat production in Kerala
df3=df2[(df2['State']=='Kerala') & (df2['Crop']=='Wheat')]
df3
# Out:
#        Crop  Crop_Year      Season   State  Area  Production  Annual_Rainfall  \
# 2375  Wheat       2012  Whole Year  Kerala   1.0         0.0           2187.6
# 2753  Wheat       2014  Whole Year  Kerala   1.0         3.0           3046.4
# 2999  Wheat       2015  Whole Year  Kerala   2.0         3.0           2602.9
# 3254  Wheat       2016  Whole Year  Kerala   1.0         1.0           2924.3
# 3513  Wheat       2017  Whole Year  Kerala   1.0         1.0           2664.8
# 3776  Wheat       2018  Whole Year  Kerala   1.4         2.0           2989.7
# 4042  Wheat       2019  Whole Year  Kerala   1.0         2.0           3119.2
#
#       Fertilizer  Pesticide  Yield
# 2375      150.80       0.31    NaN
# 2753      150.96       0.33   3.00
# 2999      315.82       0.66   1.50
# 3254      153.25       0.35   1.00
# 3513      157.44       0.38   1.00
# 3776      227.08       0.49   1.45
# 4042      171.76       0.37   2.00

# %%
#consider Area ,rainfall, fertilizer and pesticide used inthe data production =1
df3.loc[:,'Production'] = df3['Production'].fillna(1)
# Apply df3 modifications back to df2
df2.update(df3)

# %%
df3= df2[df2['Production'].isnull()]
df3
# Out:
#            Crop  Crop_Year      Season           State    Area  Production  \
# 2423   Sannhamp       2013  Whole Year  Andhra Pradesh  4734.0         NaN
# 2648    Tapioca       2014        Rabi  Andhra Pradesh    49.0         NaN
# 3323       Gram       2017      Kharif  Andhra Pradesh     1.0         NaN
# 3596    Linseed       2018      Kharif  Andhra Pradesh   151.0         NaN
# 3855  Guar seed       2019      Kharif  Andhra Pradesh     1.0         NaN
# 3856  Guar seed       2019        Rabi  Andhra Pradesh     6.0         NaN
# 3861    Linseed       2019      Kharif  Andhra Pradesh   133.0         NaN
# 3882   Sannhamp       2019      Kharif  Andhra Pradesh  3365.0         NaN
# 3883   Sannhamp       2019        Rabi  Andhra Pradesh  1133.0         NaN
# 4411     Garlic       2004  Whole Year  Andhra Pradesh   552.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2423           1062.3   684015.66    1278.18    NaN
# 2648            687.6     7397.04      16.17    NaN
# 3323            868.2      157.44       0.38    NaN
# 3596           1220.5    24492.20      52.85    NaN
# 3855            899.2      171.76       0.37    NaN
# 3856            899.2     1030.56       2.22    NaN
# 3861            899.2    22844.08      49.21    NaN
# 3882            899.2   577972.40    1245.05    NaN
# 3883            899.2   194604.08     419.21    NaN
# 4411            781.8    59803.68     115.92    NaN

# %%
#Tapioca Andhra Pradesh
# Filter the DataFrame for Andhra Pradesh and Tapioca
df2_ap_tapioca = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Tapioca')]
df2_ap_tapioca
# Out:
#          Crop  Crop_Year      Season           State     Area  Production  \
# 211   Tapioca       2000  Whole Year  Andhra Pradesh  21506.0    166124.0
# 365   Tapioca       2001  Whole Year  Andhra Pradesh  17694.0    146361.0
# 510   Tapioca       2002  Whole Year  Andhra Pradesh  13138.0     79474.0
# 619   Tapioca       2003  Whole Year  Andhra Pradesh  19456.0    122145.0
# 917   Tapioca       2005  Whole Year  Andhra Pradesh  15281.0    125986.0
# 1115  Tapioca       2006  Whole Year  Andhra Pradesh  19732.0    209152.0
# 1478  Tapioca       2008  Whole Year  Andhra Pradesh  16765.0    208052.0
# 1692  Tapioca       2009  Whole Year  Andhra Pradesh  11234.0    146366.0
# 1905  Tapioca       2010  Whole Year  Andhra Pradesh  12859.0     84686.0
# 2081  Tapioca       2011  Whole Year  Andhra Pradesh  12793.0    127953.0
# 2269  Tapioca       2012      Kharif  Andhra Pradesh  11619.0    213952.0
# 2435  Tapioca       2013      Kharif  Andhra Pradesh  10588.0    194968.0
# 2436  Tapioca       2013        Rabi  Andhra Pradesh     20.0       368.0
# 2647  Tapioca       2014      Kharif  Andhra Pradesh  10736.0    210558.0
# 2648  Tapioca       2014        Rabi  Andhra Pradesh     49.0         NaN
# 2861  Tapioca       2015      Kharif  Andhra Pradesh   8572.0    111270.0
# 2862  Tapioca       2015        Rabi  Andhra Pradesh     61.0       763.0
# 3112  Tapioca       2016      Kharif  Andhra Pradesh   7122.0     83906.0
# 3113  Tapioca       2016        Rabi  Andhra Pradesh     19.0       189.0
# 3363  Tapioca       2017      Kharif  Andhra Pradesh   7468.0     92603.0
# 3364  Tapioca       2017        Rabi  Andhra Pradesh     39.0       474.0
# 3630  Tapioca       2018      Kharif  Andhra Pradesh   7350.0     86912.0
# 3631  Tapioca       2018        Rabi  Andhra Pradesh     83.0       743.0
# 3895  Tapioca       2019      Kharif  Andhra Pradesh   6986.0     84845.0
# 3896  Tapioca       2019        Rabi  Andhra Pradesh     54.0       512.0
# 4448  Tapioca       2004  Whole Year  Andhra Pradesh  20137.0    146784.0
#
#       Annual_Rainfall  Fertilizer  Pesticide      Yield
# 211             935.6  2111244.02    5591.56   7.528000
# 365             928.4  1807088.22    4600.44   7.830000
# 510             648.1  1243774.46    3284.50   5.034286
# 619             826.0  1925754.88    4669.44   6.290000
# 917            1075.5  1832497.52    3209.01   7.207500
# 1115            845.2  2519973.72    4341.04   8.950000
# 1478            944.6  2398065.60    1508.85   9.871429
# 1692            711.0  1750481.88    1909.78   9.916667
# 1905           1297.0  2136008.49    3086.16   6.107500
# 2081            861.9  2143083.36    4221.69   9.755000
# 2269            968.7  1752145.20    3601.89  18.414000
# 2435           1062.3  1529860.12    2858.76  18.412500
# 2436           1062.3     2889.80       5.40  18.400000
# 2647            687.6  1620706.56    3542.88  18.750000
# 2648            687.6     7397.04      16.17        NaN
# 2861            940.7  1353604.52    2828.76  14.003333
# 2862            940.7     9632.51      20.13  11.060000
# 3112            890.0  1091446.50    2492.70  13.003333
# 3113            890.0     2911.75       6.65  10.087500
# 3363            868.2  1175761.92    2837.84  13.266667
# 3364            868.2     6140.16      14.82   9.530000
# 3630           1220.5  1192170.00    2572.50  12.895000
# 3631           1220.5    13462.60      29.05  11.442500
# 3895            899.2  1199915.36    2584.82  13.611667
# 3896            899.2     9275.04      19.98  14.415000
# 4448            781.8  2181642.58    4228.77   6.748000

# %%
# Filter the DataFrame for Andhra Pradesh and Tapioca for rabi season
df2_ap_tapi_rabi = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Tapioca')& (df2['Season'] == 'Rabi')]
df2_ap_tapi_rabi
# Out:
#          Crop  Crop_Year Season           State  Area  Production  \
# 2436  Tapioca       2013   Rabi  Andhra Pradesh  20.0       368.0
# 2648  Tapioca       2014   Rabi  Andhra Pradesh  49.0         NaN
# 2862  Tapioca       2015   Rabi  Andhra Pradesh  61.0       763.0
# 3113  Tapioca       2016   Rabi  Andhra Pradesh  19.0       189.0
# 3364  Tapioca       2017   Rabi  Andhra Pradesh  39.0       474.0
# 3631  Tapioca       2018   Rabi  Andhra Pradesh  83.0       743.0
# 3896  Tapioca       2019   Rabi  Andhra Pradesh  54.0       512.0
#
#       Annual_Rainfall  Fertilizer  Pesticide    Yield
# 2436           1062.3     2889.80       5.40  18.4000
# 2648            687.6     7397.04      16.17      NaN
# 2862            940.7     9632.51      20.13  11.0600
# 3113            890.0     2911.75       6.65  10.0875
# 3364            868.2     6140.16      14.82   9.5300
# 3631           1220.5    13462.60      29.05  11.4425
# 3896            899.2     9275.04      19.98  14.4150

# %%
# Plot histogram
plt.figure(figsize=(10, 6))
sns.histplot(df2_ap_tapi_rabi['Production'], kde=True,bins=30, edgecolor='black')
plt.title('Histogram of production for  Tapioca in ap in Rabi Season')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
median_prod = df2_ap_tapi_rabi['Production'].median()
median_prod
# Out:
# 493.0

# %%
# Fill NA values in the 'Production' column with the calculated mean
df2_ap_tapi_rabi['Production'].fillna(median_prod, inplace=True)
# Out:
# <ipython-input-289-aaa766d917b8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ap_tapi_rabi['Production'].fillna(median_prod, inplace=True)

# %%
df2.loc[df2_ap_tapi_rabi.index, 'Production'] = df2_ap_tapi_rabi['Production']

# %%
# Filter the DataFrame for Sanhamp in ap
df2_ap_san = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Sannhamp')]
df2_ap_san
# Out:
#           Crop  Crop_Year      Season           State    Area  Production  \
# 2423  Sannhamp       2013  Whole Year  Andhra Pradesh  4734.0         NaN
# 3882  Sannhamp       2019      Kharif  Andhra Pradesh  3365.0         NaN
# 3883  Sannhamp       2019        Rabi  Andhra Pradesh  1133.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2423           1062.3   684015.66    1278.18    NaN
# 3882            899.2   577972.40    1245.05    NaN
# 3883            899.2   194604.08     419.21    NaN

# %%
#fill production of sanhamp in ap with 0 as production sanhamp in ap not available and very less in other states
df2_ap_san['Production'].fillna(0, inplace=True)
# Out:
# <ipython-input-292-22fb3531d43e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ap_san['Production'].fillna(0, inplace=True)

# %%
df2.loc[df2_ap_san.index, 'Production'] = df2_ap_san['Production']

# %%
# Filter the DataFrame for  gram in Andhra Pradesh
df2_ap_gram = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Gram')]
df2_ap_gram
# Out:
#       Crop  Crop_Year  Season           State      Area  Production  \
# 179   Gram       2000  Kharif  Andhra Pradesh     100.0       173.0
# 180   Gram       2000    Rabi  Andhra Pradesh  200763.0    228546.0
# 332   Gram       2001  Kharif  Andhra Pradesh      91.0       101.0
# 333   Gram       2001    Rabi  Andhra Pradesh  285086.0    363033.0
# 476   Gram       2002  Kharif  Andhra Pradesh      37.0        45.0
# 477   Gram       2002    Rabi  Andhra Pradesh  390113.0    381761.0
# 585   Gram       2003  Kharif  Andhra Pradesh      52.0        90.0
# 586   Gram       2003    Rabi  Andhra Pradesh  422059.0    456464.0
# 884   Gram       2005    Rabi  Andhra Pradesh  394443.0    626974.0
# 1082  Gram       2006    Rabi  Andhra Pradesh  601745.0    653429.0
# 1445  Gram       2008    Rabi  Andhra Pradesh  606426.0    857221.0
# 1659  Gram       2009    Rabi  Andhra Pradesh  646894.0    846659.0
# 1872  Gram       2010    Rabi  Andhra Pradesh  583563.0    719248.0
# 2048  Gram       2011    Rabi  Andhra Pradesh  564754.0    519918.0
# 2232  Gram       2012    Rabi  Andhra Pradesh  681000.0    762000.0
# 2396  Gram       2013    Rabi  Andhra Pradesh  472380.0    648031.0
# 2608  Gram       2014    Rabi  Andhra Pradesh  341766.0    390967.0
# 2822  Gram       2015  Kharif  Andhra Pradesh       2.0         2.0
# 2823  Gram       2015    Rabi  Andhra Pradesh  471129.0    499784.0
# 3069  Gram       2016  Kharif  Andhra Pradesh       5.0         2.0
# 3070  Gram       2016    Rabi  Andhra Pradesh  397083.0    381035.0
# 3323  Gram       2017  Kharif  Andhra Pradesh       1.0         NaN
# 3324  Gram       2017    Rabi  Andhra Pradesh  520380.0    589124.0
# 3588  Gram       2018  Kharif  Andhra Pradesh      31.0         5.0
# 3589  Gram       2018    Rabi  Andhra Pradesh  477851.0    242641.0
# 3852  Gram       2019    Rabi  Andhra Pradesh  458579.0    558745.0
# 4106  Gram       1997    Rabi  Andhra Pradesh  146600.0     58400.0
# 4143  Gram       1998  Kharif  Andhra Pradesh     100.0       100.0
# 4144  Gram       1998    Rabi  Andhra Pradesh  145800.0    129900.0
# 4413  Gram       2004  Kharif  Andhra Pradesh     111.0        98.0
# 4414  Gram       2004    Rabi  Andhra Pradesh  341228.0    345312.0
# 4460  Gram       2007    Rabi  Andhra Pradesh  630000.0    912000.0
# 4920  Gram       1999    Rabi  Andhra Pradesh  162961.0     95087.0
#
#       Annual_Rainfall    Fertilizer  Pesticide     Yield
# 179             935.6  9.817000e+03      26.00  1.157500
# 180             935.6  1.970890e+07   52198.38  1.414500
# 332             928.4  9.293830e+03      23.66  1.092857
# 333             928.4  2.911583e+07   74122.36  1.419000
# 476             648.1  3.502790e+03       9.25  1.007500
# 477             648.1  3.693200e+07   97528.25  1.162381
# 585             826.0  5.146960e+03      12.48  1.656667
# 586             826.0  4.177540e+07  101294.16  1.338947
# 884            1075.5  4.730160e+07   82833.03  1.602632
# 1082            845.2  7.684885e+07  132383.90  1.465000
# 1445            944.6  8.674318e+07   54578.34  1.627619
# 1659            711.0  1.007990e+08  109971.98  1.386818
# 1872           1297.0  9.693565e+07  140055.12  1.360000
# 2048            861.9  9.460759e+07  186368.82  1.110500
# 2232            968.7  1.026948e+08  211110.00  1.322000
# 2396           1062.3  6.825419e+07  127542.60  1.639091
# 2608            687.6  5.159300e+07  112782.78  1.636154
# 2822            940.7  3.158200e+02       0.66  1.000000
# 2823            940.7  7.439598e+07  155472.57  1.478333
# 3069            890.0  7.662500e+02       1.75  0.400000
# 3070            890.0  6.085297e+07  138979.05  1.210000
# 3323            868.2  1.574400e+02       0.38       NaN
# 3324            868.2  8.192863e+07  197744.40  1.341818
# 3588           1220.5  5.028200e+03      10.85  0.500000
# 3589           1220.5  7.750743e+07  167247.85  1.027273
# 3852            899.2  7.876553e+07  169674.23  1.443636
# 4106            927.5  1.395192e+07   45446.00  0.338000
# 4143           1048.3  9.880000e+03      29.00  1.000000
# 4144           1048.3  1.440504e+07   42282.00  0.953750
# 4413            781.8  1.202574e+04      23.31  0.885000
# 4414            781.8  3.696864e+07   71657.88  1.090000
# 4460           1004.2  8.404200e+07  100800.00  1.280000
# 4920            650.4  1.729505e+07   43999.47  0.824762

# %%
# Filter the DataFrame for  gram in Andhra Pradesh in kharif season
df2_ap_gram_kharif = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Gram')& (df2['Season'] == 'Kharif')]
df2_ap_gram_kharif
# Out:
#       Crop  Crop_Year  Season           State   Area  Production  \
# 179   Gram       2000  Kharif  Andhra Pradesh  100.0       173.0
# 332   Gram       2001  Kharif  Andhra Pradesh   91.0       101.0
# 476   Gram       2002  Kharif  Andhra Pradesh   37.0        45.0
# 585   Gram       2003  Kharif  Andhra Pradesh   52.0        90.0
# 2822  Gram       2015  Kharif  Andhra Pradesh    2.0         2.0
# 3069  Gram       2016  Kharif  Andhra Pradesh    5.0         2.0
# 3323  Gram       2017  Kharif  Andhra Pradesh    1.0         NaN
# 3588  Gram       2018  Kharif  Andhra Pradesh   31.0         5.0
# 4143  Gram       1998  Kharif  Andhra Pradesh  100.0       100.0
# 4413  Gram       2004  Kharif  Andhra Pradesh  111.0        98.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 179             935.6     9817.00      26.00  1.157500
# 332             928.4     9293.83      23.66  1.092857
# 476             648.1     3502.79       9.25  1.007500
# 585             826.0     5146.96      12.48  1.656667
# 2822            940.7      315.82       0.66  1.000000
# 3069            890.0      766.25       1.75  0.400000
# 3323            868.2      157.44       0.38       NaN
# 3588           1220.5     5028.20      10.85  0.500000
# 4143           1048.3     9880.00      29.00  1.000000
# 4413            781.8    12025.74      23.31  0.885000

# %%
#sorting wrt year
df2_ap_gram_kharif = df2_ap_gram_kharif.sort_values(by='Crop_Year')
df2_ap_gram_kharif
# Out:
#       Crop  Crop_Year  Season           State   Area  Production  \
# 4143  Gram       1998  Kharif  Andhra Pradesh  100.0       100.0
# 179   Gram       2000  Kharif  Andhra Pradesh  100.0       173.0
# 332   Gram       2001  Kharif  Andhra Pradesh   91.0       101.0
# 476   Gram       2002  Kharif  Andhra Pradesh   37.0        45.0
# 585   Gram       2003  Kharif  Andhra Pradesh   52.0        90.0
# 4413  Gram       2004  Kharif  Andhra Pradesh  111.0        98.0
# 2822  Gram       2015  Kharif  Andhra Pradesh    2.0         2.0
# 3069  Gram       2016  Kharif  Andhra Pradesh    5.0         2.0
# 3323  Gram       2017  Kharif  Andhra Pradesh    1.0         NaN
# 3588  Gram       2018  Kharif  Andhra Pradesh   31.0         5.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4143           1048.3     9880.00      29.00  1.000000
# 179             935.6     9817.00      26.00  1.157500
# 332             928.4     9293.83      23.66  1.092857
# 476             648.1     3502.79       9.25  1.007500
# 585             826.0     5146.96      12.48  1.656667
# 4413            781.8    12025.74      23.31  0.885000
# 2822            940.7      315.82       0.66  1.000000
# 3069            890.0      766.25       1.75  0.400000
# 3323            868.2      157.44       0.38       NaN
# 3588           1220.5     5028.20      10.85  0.500000

# %%
#filling null values according to the trend(from line plot)
df2_ap_gram['Production'].fillna(2, inplace=True)
df2.loc[df2_ap_gram.index, 'Production'] = df2_ap_gram['Production']
# Out:
# <ipython-input-297-89fc79a9cce0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ap_gram['Production'].fillna(2, inplace=True)

# %%
## Filter the DataFrame for linseed in Andhra Pradesh
df2_ap_lin = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Linseed')]
df2_ap_lin
# Out:
#          Crop  Crop_Year  Season           State    Area  Production  \
# 187   Linseed       2000    Rabi  Andhra Pradesh  5486.0      1093.0
# 340   Linseed       2001    Rabi  Andhra Pradesh  5872.0      1419.0
# 484   Linseed       2002    Rabi  Andhra Pradesh  4070.0      1238.0
# 593   Linseed       2003    Rabi  Andhra Pradesh  4542.0      1193.0
# 891   Linseed       2005    Rabi  Andhra Pradesh  3845.0      1435.0
# 1089  Linseed       2006    Rabi  Andhra Pradesh  2830.0       777.0
# 1452  Linseed       2008    Rabi  Andhra Pradesh   927.0       347.0
# 1666  Linseed       2009    Rabi  Andhra Pradesh   673.0       100.0
# 1879  Linseed       2010    Rabi  Andhra Pradesh  1129.0       258.0
# 2055  Linseed       2011    Rabi  Andhra Pradesh   744.0       158.0
# 2239  Linseed       2012  Kharif  Andhra Pradesh   422.0       203.0
# 2403  Linseed       2013  Kharif  Andhra Pradesh   473.0       228.0
# 2615  Linseed       2014  Kharif  Andhra Pradesh   361.0       174.0
# 2830  Linseed       2015  Kharif  Andhra Pradesh   259.0       125.0
# 3078  Linseed       2016  Kharif  Andhra Pradesh   219.0       106.0
# 3331  Linseed       2017  Kharif  Andhra Pradesh   224.0       108.0
# 3596  Linseed       2018  Kharif  Andhra Pradesh   151.0         NaN
# 3861  Linseed       2019  Kharif  Andhra Pradesh   133.0         NaN
# 4421  Linseed       2004    Rabi  Andhra Pradesh  4181.0       467.0
# 4927  Linseed       1999    Rabi  Andhra Pradesh  5864.0       506.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 187             935.6   538560.62    1426.36  0.207500
# 340             928.4   599707.36    1526.72  0.218333
# 484             648.1   385306.90    1017.50  0.322857
# 593             826.0   449567.16    1090.08  0.210000
# 891            1075.5   461092.40     807.45  0.371667
# 1089            845.2   361419.30     622.60  0.266000
# 1452            944.6   132598.08      83.43  0.384000
# 1666            711.0   104866.86     114.41  0.155000
# 1879           1297.0   187538.19     270.96  0.150000
# 2055            861.9   124634.88     245.52  0.200000
# 2239            968.7    63637.60     130.82  0.455000
# 2403           1062.3    68343.77     127.71  0.455000
# 2615            687.6    54496.56     119.13  0.480000
# 2830            940.7    40898.69      85.47  0.640000
# 3078            890.0    33561.75      76.65  0.480000
# 3331            868.2    35266.56      85.12  0.490000
# 3596           1220.5    24492.20      52.85       NaN
# 3861            899.2    22844.08      49.21       NaN
# 4421            781.8   452969.54     878.01  0.126667
# 4927            650.4   622346.32    1583.28  0.117500

# %%
# Filter the DataFrame for  linseed in Andhra Pradesh in kharif season
df2_ap_lin_kharif = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Linseed')& (df2['Season'] == 'Kharif')]
df2_ap_lin_kharif
# Out:
#          Crop  Crop_Year  Season           State   Area  Production  \
# 2239  Linseed       2012  Kharif  Andhra Pradesh  422.0       203.0
# 2403  Linseed       2013  Kharif  Andhra Pradesh  473.0       228.0
# 2615  Linseed       2014  Kharif  Andhra Pradesh  361.0       174.0
# 2830  Linseed       2015  Kharif  Andhra Pradesh  259.0       125.0
# 3078  Linseed       2016  Kharif  Andhra Pradesh  219.0       106.0
# 3331  Linseed       2017  Kharif  Andhra Pradesh  224.0       108.0
# 3596  Linseed       2018  Kharif  Andhra Pradesh  151.0         NaN
# 3861  Linseed       2019  Kharif  Andhra Pradesh  133.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2239            968.7    63637.60     130.82  0.455
# 2403           1062.3    68343.77     127.71  0.455
# 2615            687.6    54496.56     119.13  0.480
# 2830            940.7    40898.69      85.47  0.640
# 3078            890.0    33561.75      76.65  0.480
# 3331            868.2    35266.56      85.12  0.490
# 3596           1220.5    24492.20      52.85    NaN
# 3861            899.2    22844.08      49.21    NaN

# %%
#filling null values according to the trend(from line plot)
df2_ap_lin['Production'].fillna(108, inplace=True)
df2.loc[df2_ap_lin.index, 'Production'] = df2_ap_lin['Production']
# Out:
# <ipython-input-300-7ae80b4163e3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_ap_lin['Production'].fillna(108, inplace=True)

# %%
# Filter the DataFrame for  garlic in Andhra Pradesh in whole year
df2_ap_gar_wy = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Garlic')& (df2['Season'] == 'Whole Year')]
df2_ap_gar_wy
# Out:
#         Crop  Crop_Year      Season           State   Area  Production  \
# 882   Garlic       2005  Whole Year  Andhra Pradesh  800.0         0.0
# 1657  Garlic       2009  Whole Year  Andhra Pradesh  530.0      1565.0
# 1870  Garlic       2010  Whole Year  Andhra Pradesh  464.0       978.0
# 2046  Garlic       2011  Whole Year  Andhra Pradesh  429.0       930.0
# 4411  Garlic       2004  Whole Year  Andhra Pradesh  552.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 882            1075.5    95936.00     168.00       NaN
# 1657            711.0    82584.60      90.10  2.556667
# 1870           1297.0    77075.04     111.36  1.968000
# 2046            861.9    71866.08     141.57  2.136000
# 4411            781.8    59803.68     115.92       NaN

# %%
#sorting wrt year
df2_ap_gar_wy = df2_ap_gar_wy.sort_values(by='Crop_Year')
df2_ap_gar_wy
# Out:
#         Crop  Crop_Year      Season           State   Area  Production  \
# 4411  Garlic       2004  Whole Year  Andhra Pradesh  552.0         NaN
# 882   Garlic       2005  Whole Year  Andhra Pradesh  800.0         0.0
# 1657  Garlic       2009  Whole Year  Andhra Pradesh  530.0      1565.0
# 1870  Garlic       2010  Whole Year  Andhra Pradesh  464.0       978.0
# 2046  Garlic       2011  Whole Year  Andhra Pradesh  429.0       930.0
#
#       Annual_Rainfall  Fertilizer  Pesticide     Yield
# 4411            781.8    59803.68     115.92       NaN
# 882            1075.5    95936.00     168.00       NaN
# 1657            711.0    82584.60      90.10  2.556667
# 1870           1297.0    77075.04     111.36  1.968000
# 2046            861.9    71866.08     141.57  2.136000

# %%
#filling null values according to the trend(from line plot)
df2_ap_gar_wy['Production'].fillna(0, inplace=True)
df2.loc[df2_ap_gar_wy.index, 'Production'] = df2_ap_gar_wy['Production']

# %%
# Filter the DataFrame for  guar seeed in Andhra Pradesh in kharif season
df2_ap_guar_kharif = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Guar seed')& (df2['Season'] == 'Kharif')]
df2_ap_guar_kharif
# Out:
#            Crop  Crop_Year  Season           State  Area  Production  \
# 3855  Guar seed       2019  Kharif  Andhra Pradesh   1.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 3855            899.2      171.76       0.37    NaN

# %%
# Filter the DataFrame for  guar seeed in Andhra Pradesh in rabi season
df2_ap_guar_rabi = df2[(df2['State'] == 'Andhra Pradesh') & (df2['Crop'] == 'Guar seed')& (df2['Season'] == 'Rabi')]
df2_ap_guar_rabi
# Out:
#            Crop  Crop_Year Season           State  Area  Production  \
# 3073  Guar seed       2016   Rabi  Andhra Pradesh  42.0        80.0
# 3856  Guar seed       2019   Rabi  Andhra Pradesh   6.0         NaN
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 3073            890.0     6436.50      14.70    1.9
# 3856            899.2     1030.56       2.22    NaN

# %%
df2_guar = df2[(df2['Crop'] == 'Guar seed')]
df2_guar
# Out:
#            Crop  Crop_Year      Season           State      Area  Production  \
# 3073  Guar seed       2016        Rabi  Andhra Pradesh      42.0        80.0
# 3855  Guar seed       2019      Kharif  Andhra Pradesh       1.0         NaN
# 3856  Guar seed       2019        Rabi  Andhra Pradesh       6.0         NaN
# 4275  Guar seed       1999  Whole Year      Tamil Nadu  332323.0   3514258.0
#
#       Annual_Rainfall   Fertilizer  Pesticide      Yield
# 3073            890.0      6436.50      14.70   1.900000
# 3855            899.2       171.76       0.37        NaN
# 3856            899.2      1030.56       2.22        NaN
# 4275            922.8  35269439.99   89727.21  10.651481

# %%
#filling null values with 0 as the total production is very less and area is less
df2_guar['Production'].fillna(0, inplace=True)
# Out:
# <ipython-input-307-647649a1e90f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2_guar['Production'].fillna(0, inplace=True)

# %%
df2.loc[df2_guar.index, 'Production'] = df2_guar['Production']

# %%
df2.isna().sum()
# Out:
# Crop                0
# Crop_Year           0
# Season              0
# State               0
# Area                0
# Production          0
# Annual_Rainfall     0
# Fertilizer          0
# Pesticide           0
# Yield              47
# dtype: int64

# %%
#Saving the entries with yield Null values to use it as validation data
df4=df2[df2['Yield'].isna()]
df4
# Out:
#                    Crop  Crop_Year      Season           State       Area  \
# 624      other oilseeds       2003        Rabi  Andhra Pradesh   14609.00
# 723            Arecanut       2003  Whole Year      Tamil Nadu    5219.00
# 855          Niger seed       2004      Kharif      Tamil Nadu    1239.00
# 882              Garlic       2005  Whole Year  Andhra Pradesh     800.00
# 1029              Maize       2005      Kharif      Tamil Nadu  202830.00
# 1030              Mesta       2005      Kharif      Tamil Nadu       1.00
# 1032         Niger seed       2005      Kharif      Tamil Nadu     638.00
# 1039           Sannhamp       2005      Kharif      Tamil Nadu      10.00
# 1042           Soyabean       2005      Kharif      Tamil Nadu     630.00
# 2351      Cowpea(Lobia)       2012  Whole Year          Kerala    1085.00
# 2355         Horse-gram       2012  Whole Year          Kerala     105.00
# 2358  Moong(Green Gram)       2012  Whole Year          Kerala     101.00
# 2359              Onion       2012  Whole Year          Kerala      40.00
# 2374               Urad       2012  Whole Year          Kerala     265.00
# 2375              Wheat       2012  Whole Year          Kerala       1.00
# 2423           Sannhamp       2013  Whole Year  Andhra Pradesh    4734.00
# 2518      Cowpea(Lobia)       2013  Whole Year          Kerala     775.00
# 2522         Horse-gram       2013  Whole Year          Kerala      69.00
# 2525  Moong(Green Gram)       2013  Whole Year          Kerala     121.00
# 2526              Onion       2013  Whole Year          Kerala     103.00
# 2540               Urad       2013  Whole Year          Kerala     374.00
# 2648            Tapioca       2014        Rabi  Andhra Pradesh      49.00
# 2730      Cowpea(Lobia)       2014  Whole Year          Kerala    1004.00
# 2734         Horse-gram       2014  Whole Year          Kerala     111.00
# 2737  Moong(Green Gram)       2014  Whole Year          Kerala     163.00
# 2738              Onion       2014  Whole Year          Kerala      61.00
# 2752               Urad       2014  Whole Year          Kerala     403.00
# 2984              Onion       2015  Whole Year          Kerala      27.00
# 3240              Onion       2016  Whole Year          Kerala      31.00
# 3323               Gram       2017      Kharif  Andhra Pradesh       1.00
# 3449              Mesta       2017  Whole Year       Karnataka       9.00
# 3499              Onion       2017  Whole Year          Kerala       9.00
# 3521          Cashewnut       2017  Whole Year      Tamil Nadu   85883.00
# 3596            Linseed       2018      Kharif  Andhra Pradesh     151.00
# 3762              Onion       2018  Whole Year          Kerala       5.21
# 3855          Guar seed       2019      Kharif  Andhra Pradesh       1.00
# 3856          Guar seed       2019        Rabi  Andhra Pradesh       6.00
# 3861            Linseed       2019      Kharif  Andhra Pradesh     133.00
# 3882           Sannhamp       2019      Kharif  Andhra Pradesh    3365.00
# 3883           Sannhamp       2019        Rabi  Andhra Pradesh    1133.00
# 3975              Mesta       2019  Whole Year       Karnataka      55.00
# 4411             Garlic       2004  Whole Year  Andhra Pradesh     552.00
# 4774         Horse-gram       2017      Kharif       Telangana     237.00
# 4775         Horse-gram       2017        Rabi       Telangana     963.00
# 4890             Potato       2019      Kharif       Telangana       3.00
# 4896          Safflower       2019      Kharif       Telangana       1.00
# 4913              Wheat       2019      Kharif       Telangana       1.00
#
#       Production  Annual_Rainfall    Fertilizer   Pesticide  Yield
# 624         0.00            826.0  1.445999e+06   3506.1600    NaN
# 723      7390.00            345.6  5.165766e+05   1252.5600    NaN
# 855         0.00           1034.0  1.342333e+05    260.1900    NaN
# 882         0.00           1075.5  9.593600e+04    168.0000    NaN
# 1029  1483163.00           1364.1  2.432337e+07  42594.3000    NaN
# 1030        0.00           1364.1  1.199200e+02      0.2100    NaN
# 1032        0.00           1364.1  7.650896e+04    133.9800    NaN
# 1039        0.00           1364.1  1.199200e+03      2.1000    NaN
# 1042        0.00           1364.1  7.554960e+04    132.3000    NaN
# 2351        0.00           2187.6  1.636180e+05    336.3500    NaN
# 2355        0.00           2187.6  1.583400e+04     32.5500    NaN
# 2358        0.00           2187.6  1.523080e+04     31.3100    NaN
# 2359        0.00           2187.6  6.032000e+03     12.4000    NaN
# 2374        0.00           2187.6  3.996200e+04     82.1500    NaN
# 2375        0.00           2187.6  1.508000e+02      0.3100    NaN
# 2423        0.00           1062.3  6.840157e+05   1278.1800    NaN
# 2518        0.00           3255.4  1.119798e+05    209.2500    NaN
# 2522        0.00           3255.4  9.969810e+03     18.6300    NaN
# 2525        0.00           3255.4  1.748329e+04     32.6700    NaN
# 2526        0.00           3255.4  1.488247e+04     27.8100    NaN
# 2540        0.00           3255.4  5.403926e+04    100.9800    NaN
# 2648      493.00            687.6  7.397040e+03     16.1700    NaN
# 2730        0.00           3046.4  1.515638e+05    331.3200    NaN
# 2734        0.00           3046.4  1.675656e+04     36.6300    NaN
# 2737        0.00           3046.4  2.460648e+04     53.7900    NaN
# 2738        0.00           3046.4  9.208560e+03     20.1300    NaN
# 2752        0.00           3046.4  6.083688e+04    132.9900    NaN
# 2984        0.00           2602.9  4.263570e+03      8.9100    NaN
# 3240        0.00           2924.3  4.750750e+03     10.8500    NaN
# 3323        2.00            868.2  1.574400e+02      0.3800    NaN
# 3449       11.25           1111.7  1.416960e+03      3.4200    NaN
# 3499        0.00           2664.8  1.416960e+03      3.4200    NaN
# 3521    19701.00            970.9  1.352142e+07  32635.5400    NaN
# 3596      108.00           1220.5  2.449220e+04     52.8500    NaN
# 3762        0.00           2989.7  8.450620e+02      1.8235    NaN
# 3855        0.00            899.2  1.717600e+02      0.3700    NaN
# 3856        0.00            899.2  1.030560e+03      2.2200    NaN
# 3861      108.00            899.2  2.284408e+04     49.2100    NaN
# 3882        0.00            899.2  5.779724e+05   1245.0500    NaN
# 3883        0.00            899.2  1.946041e+05    419.2100    NaN
# 3975       68.75           1422.3  9.446800e+03     20.3500    NaN
# 4411        0.00            781.8  5.980368e+04    115.9200    NaN
# 4774       92.00            815.7  3.731328e+04     90.0600    NaN
# 4775      467.00            815.7  1.516147e+05    365.9400    NaN
# 4890        9.00           1031.7  5.152800e+02      1.1100    NaN
# 4896        1.00           1031.7  1.717600e+02      0.3700    NaN
# 4913        1.00           1031.7  1.717600e+02      0.3700    NaN

# %%
#Drop all the yield Nan Columns from main dataframe df2
df2=df2.dropna()
df2.isna().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
d=df2[df2['Production']==0]
d
# Out:
#                Crop  Crop_Year      Season           State     Area  \
# 506        Soyabean       2002      Kharif  Andhra Pradesh  41284.0
# 537  other oilseeds       2002  Whole Year          Kerala   2253.0
#
#      Production  Annual_Rainfall  Fertilizer  Pesticide  Yield
# 506         0.0            648.1  3908356.28   10321.00    0.0
# 537         0.0           2511.2   213291.51     563.25    0.0

# %%
df2.shape
# Out:
# (5067, 10)

# %%
df2.to_csv('cleaned_data.csv', index=False)

# %%
# Loop through each numeric column and create a boxplot
# Identify numeric columns in your DataFrame 'df2'
numeric_columns = df2.select_dtypes(include=['number']).columns
for column in numeric_columns:
    plt.figure(figsize=(10, 6))  # Set the size of each individual plot
    sns.boxplot(x='Crop', y=column, data=df2,color='green')
    plt.xticks(rotation=90)
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
# AREA OUTLIERS
#Checking for outlier values whether it need to be clipped or not. Finding genuine outliers and pecentage of outliers.
def find_outliers(group):
    q1 = group['Area'].quantile(0.25)
    q3 = group['Area'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Area'] < lower_bound) | (group['Area'] > upper_bound)]
    return outliers

outliers = df2.groupby('Crop').apply(find_outliers).reset_index(drop=True)
#print(outliers)
outliers
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 5.90%
#           Crop  Crop_Year      Season           State       Area  Production  \
# 0     Arecanut       2016  Whole Year       Karnataka   254640.0   2586795.0
# 1     Arecanut       2017  Whole Year       Karnataka   279459.0   3030925.0
# 2     Arecanut       2018  Whole Year       Karnataka   476378.0   4253453.0
# 3     Arecanut       2019  Whole Year       Karnataka   500522.0   5409381.0
# 4    Arhar/Tur       2016      Kharif       Karnataka  1213836.0   1212287.0
# ..         ...        ...         ...             ...        ...         ...
# 294       Urad       1998      Kharif      Tamil Nadu   446130.0    218245.0
# 295       Urad       1999      Kharif      Tamil Nadu   439604.0    218071.0
# 296       Urad       2000      Kharif      Tamil Nadu   503982.0    244412.0
# 297       Urad       2007        Rabi  Andhra Pradesh   407000.0    201000.0
# 298       Urad       1999        Rabi  Andhra Pradesh   380593.0    246988.0
#
#      Annual_Rainfall    Fertilizer  Pesticide      Yield
# 0             1147.2  3.902358e+07   89124.00  10.121818
# 1             1111.7  4.399802e+07  106194.42  10.920000
# 2             1419.1  7.726851e+07  166732.30   9.040000
# 3             1422.3  8.596966e+07  185193.14  10.772400
# 4             1147.2  1.860204e+08  424842.60   0.686667
# ..               ...           ...        ...        ...
# 294           1077.1  4.407764e+07  129377.70   0.505926
# 295            922.8  4.665517e+07  118693.08   0.517778
# 296            971.1  4.947591e+07  131035.32   0.517778
# 297           1004.2  5.429380e+07   65120.00   0.600000
# 298            650.4  4.039234e+07  102760.11   0.508000
#
# [299 rows x 10 columns]

# %%
# ANNUAL_RAINFALL OUTLIERS
#Checking for outlier values whether it need to be clipped or not. Finding genuine outliers and pecentage of outliers.
def find_outliers(group):
    q1 = group['Annual_Rainfall'].quantile(0.25)
    q3 = group['Annual_Rainfall'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Annual_Rainfall'] < lower_bound) | (group['Annual_Rainfall'] > upper_bound)]
    return outliers

outliers = df2.groupby('State').apply(find_outliers).reset_index(drop=True)
#print(outliers)
outliers
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 9.53%
#           Crop  Crop_Year      Season           State       Area  Production  \
# 0     Arecanut       2010  Whole Year  Andhra Pradesh      438.0       195.0
# 1    Arhar/Tur       2010      Kharif  Andhra Pradesh   629980.0    261286.0
# 2    Arhar/Tur       2010        Rabi  Andhra Pradesh     8123.0      4101.0
# 3        Bajra       2010      Kharif  Andhra Pradesh    51338.0     84908.0
# 4        Bajra       2010        Rabi  Andhra Pradesh    15988.0     17254.0
# ..         ...        ...         ...             ...        ...         ...
# 478       Rice       2012      Kharif      Tamil Nadu  1493276.0   4050334.0
# 479    Sesamum       2012  Whole Year      Tamil Nadu    33181.0     17179.0
# 480  Sugarcane       2012  Whole Year      Tamil Nadu   348379.0  34014097.0
# 481  Sunflower       2012      Kharif      Tamil Nadu    10782.0     11374.0
# 482       Urad       2012      Kharif      Tamil Nadu   208625.0     88706.0
#
#      Annual_Rainfall    Fertilizer  Pesticide      Yield
# 0             1297.0  7.275618e+04     105.12   0.443333
# 1             1297.0  1.046460e+08  151195.20   0.466364
# 2             1297.0  1.349312e+06    1949.52   0.483333
# 3             1297.0  8.527755e+06   12321.12   1.229444
# 4             1297.0  2.655767e+06    3837.12   1.454545
# ..               ...           ...        ...        ...
# 478            706.8  2.251860e+08  462915.56   3.293226
# 479            706.8  5.003695e+06   10286.11   0.477241
# 480            706.8  5.253555e+07  107997.49  93.543548
# 481            706.8  1.625926e+06    3342.42   1.136400
# 482            706.8  3.146065e+07   64673.75   0.474667
#
# [483 rows x 10 columns]

# %%
#FERTILIZER outliers
def find_outliers(group):
    q1 = group['Fertilizer'].quantile(0.25)
    q3 = group['Fertilizer'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Fertilizer'] < lower_bound) | (group['Fertilizer'] > upper_bound)]
    return outliers

outliers = df2.groupby('Crop').apply(find_outliers).reset_index(drop=True)
#print(outliers)
outliers
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 5.55%
#          Crop  Crop_Year      Season           State      Area  Production  \
# 0    Arecanut       2015  Whole Year       Karnataka  247927.0   2430194.0
# 1    Arecanut       2016  Whole Year       Karnataka  254640.0   2586795.0
# 2    Arecanut       2017  Whole Year       Karnataka  279459.0   3030925.0
# 3    Arecanut       2018  Whole Year       Karnataka  476378.0   4253453.0
# 4    Arecanut       2019  Whole Year       Karnataka  500522.0   5409381.0
# ..        ...        ...         ...             ...       ...         ...
# 276      Urad       2019        Rabi  Andhra Pradesh  287929.0    315055.0
# 277      Urad       2019        Rabi      Tamil Nadu  362726.0    281577.0
# 278      Urad       2000      Kharif      Tamil Nadu  503982.0    244412.0
# 279      Urad       2007        Rabi  Andhra Pradesh  407000.0    201000.0
# 280      Urad       2010      Kharif      Tamil Nadu  304432.0    123011.0
#
#      Annual_Rainfall   Fertilizer  Pesticide      Yield
# 0             1024.9  39150152.57   81815.91  10.210476
# 1             1147.2  39023580.00   89124.00  10.121818
# 2             1111.7  43998024.96  106194.42  10.920000
# 3             1419.1  77268511.60  166732.30   9.040000
# 4             1422.3  85969658.72  185193.14  10.772400
# ..               ...          ...        ...        ...
# 276            899.2  49454685.04  106533.73   0.944615
# 277            910.1  62301817.76  134208.62   0.759000
# 278            971.1  49475912.94  131035.32   0.517778
# 279           1004.2  54293800.00   65120.00   0.600000
# 280           1095.2  50569199.52   73063.68   0.484667
#
# [281 rows x 10 columns]

# %%
#PESTICIDE Outliers
def find_outliers(group):
    q1 = group['Pesticide'].quantile(0.25)
    q3 = group['Pesticide'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Pesticide'] < lower_bound) | (group['Pesticide'] > upper_bound)]
    return outliers

outliers = df2.groupby('Crop').apply(find_outliers).reset_index(drop=True)
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 5.98%
#          Crop  Crop_Year      Season           State      Area  Production  \
# 0    Arecanut       2015  Whole Year       Karnataka  247927.0   2430194.0
# 1    Arecanut       2016  Whole Year       Karnataka  254640.0   2586795.0
# 2    Arecanut       2017  Whole Year       Karnataka  279459.0   3030925.0
# 3    Arecanut       2018  Whole Year       Karnataka  476378.0   4253453.0
# 4    Arecanut       2019  Whole Year       Karnataka  500522.0   5409381.0
# ..        ...        ...         ...             ...       ...         ...
# 298      Urad       1998        Rabi  Andhra Pradesh  354800.0    230600.0
# 299      Urad       1998      Kharif      Tamil Nadu  446130.0    218245.0
# 300      Urad       1999      Kharif      Tamil Nadu  439604.0    218071.0
# 301      Urad       2000      Kharif      Tamil Nadu  503982.0    244412.0
# 302      Urad       1999        Rabi  Andhra Pradesh  380593.0    246988.0
#
#      Annual_Rainfall   Fertilizer  Pesticide      Yield
# 0             1024.9  39150152.57   81815.91  10.210476
# 1             1147.2  39023580.00   89124.00  10.121818
# 2             1111.7  43998024.96  106194.42  10.920000
# 3             1419.1  77268511.60  166732.30   9.040000
# 4             1422.3  85969658.72  185193.14  10.772400
# ..               ...          ...        ...        ...
# 298           1048.3  35054240.00  102892.00   0.544118
# 299           1077.1  44077644.00  129377.70   0.505926
# 300            922.8  46655172.52  118693.08   0.517778
# 301            971.1  49475912.94  131035.32   0.517778
# 302            650.4  40392335.09  102760.11   0.508000
#
# [303 rows x 10 columns]

# %%
#PRODUCTION Outliers
def find_outliers(group):
    q1 = group['Production'].quantile(0.25)
    q3 = group['Production'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Production'] < lower_bound) | (group['Production'] > upper_bound)]
    return outliers

outliers = df2.groupby('Crop').apply(find_outliers).reset_index(drop=True)
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 6.43%
#          Crop  Crop_Year      Season           State      Area  Production  \
# 0    Arecanut       1998  Whole Year       Karnataka   98047.0    648365.0
# 1    Arecanut       2005  Whole Year       Karnataka  161151.0   1033658.0
# 2    Arecanut       2007  Whole Year       Karnataka  174404.0   1114484.0
# 3    Arecanut       2008  Whole Year       Karnataka  184515.0   1174591.0
# 4    Arecanut       2009  Whole Year       Karnataka  195802.0   1243385.0
# ..        ...        ...         ...             ...       ...         ...
# 321      Urad       1999      Kharif      Tamil Nadu  439604.0    218071.0
# 322      Urad       2000      Kharif      Tamil Nadu  503982.0    244412.0
# 323      Urad       2004        Rabi  Andhra Pradesh  351048.0    223561.0
# 324      Urad       2007        Rabi  Andhra Pradesh  407000.0    201000.0
# 325      Urad       1999        Rabi  Andhra Pradesh  380593.0    246988.0
#
#      Annual_Rainfall   Fertilizer  Pesticide     Yield
# 0             1260.8   9687043.60   28433.63  6.232000
# 1             1316.2  19325227.92   33841.71  6.212381
# 2             1323.3  23265493.60   27904.64  6.211429
# 3             1164.1  26393025.60   16606.35  6.214286
# 4             1321.0  30509867.64   33286.34  6.210476
# ..               ...          ...        ...       ...
# 321            922.8  46655172.52  118693.08  0.517778
# 322            971.1  49475912.94  131035.32  0.517778
# 323            781.8  38032540.32   73720.08  0.608947
# 324           1004.2  54293800.00   65120.00  0.600000
# 325            650.4  40392335.09  102760.11  0.508000
#
# [326 rows x 10 columns]

# %%
#YIELD Outliers
def find_outliers(group):
    q1 = group['Yield'].quantile(0.25)
    q3 = group['Yield'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = group[(group['Yield'] < lower_bound) | (group['Yield'] > upper_bound)]
    return outliers

outliers = df2.groupby('Crop').apply(find_outliers).reset_index(drop=True)
total_data_points = df2.shape[0]
number_of_outliers = outliers.shape[0]
percentage_of_outliers = (number_of_outliers / total_data_points) * 100

print(f"Percentage of outliers: {percentage_of_outliers:.2f}%")
outliers
# Out:
# Percentage of outliers: 4.07%
#          Crop  Crop_Year      Season           State      Area  Production  \
# 0    Arecanut       1998  Whole Year       Karnataka   98047.0    648365.0
# 1    Arecanut       2005  Whole Year       Karnataka  161151.0   1033658.0
# 2    Arecanut       2007  Whole Year       Karnataka  174404.0   1114484.0
# 3    Arecanut       2008  Whole Year       Karnataka  184515.0   1174591.0
# 4    Arecanut       2009  Whole Year       Karnataka  195802.0   1243385.0
# ..        ...        ...         ...             ...       ...         ...
# 201      Urad       2019        Rabi       Telangana    6816.0     12269.0
# 202     Wheat       2014  Whole Year          Kerala       1.0         3.0
# 203     Wheat       2016        Rabi  Andhra Pradesh      33.0        76.0
# 204     Wheat       2019  Whole Year          Kerala       1.0         2.0
# 205     Wheat       2015        Rabi       Telangana    4952.0     16902.0
#
#      Annual_Rainfall   Fertilizer  Pesticide     Yield
# 0             1260.8   9687043.60   28433.63  6.232000
# 1             1316.2  19325227.92   33841.71  6.212381
# 2             1323.3  23265493.60   27904.64  6.211429
# 3             1164.1  26393025.60   16606.35  6.214286
# 4             1321.0  30509867.64   33286.34  6.210476
# ..               ...          ...        ...       ...
# 201           1031.7   1170716.16    2521.92  1.787692
# 202           3046.4       150.96       0.33  3.000000
# 203            890.0      5057.25      11.55  2.155000
# 204           3119.2       171.76       0.37  2.000000
# 205            747.9    781970.32    1634.16  2.947500
#
# [206 rows x 10 columns]

# %% [markdown]
# As per our research we found that the shown outliers could be genuine values. Therefore we are currently decided not to clip the values.
# When Not to Clip Outliers
#
#  1.Natural Variability: If outliers are natural variations in the data (e.g., rare but valid events), they should be kept to maintain the integrity of the dataset.
# 2. Small Sample Sizes: Removing outliers in small datasets can result in loss of
# valuable information and lead to misleading conclusions.
# 3.Specific Analysis: For certain types of analysis, such as anomaly detection,
# outliers are the primary focus and should not be removed.

# %% [markdown]
# # **Binary Encoding**
# Binary encoding is a method to convert categorical variables into binary (0 and 1) format. This is particularly useful for machine learning models that require numerical input. Binary encoding is efficient and often works well with high cardinality categorical data.

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.6.3-py2.py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.25.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.14.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (2.0.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category_encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category_encoders) (24.1)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.6.3

# %%
import category_encoders as ce
# Create the binary encoder
encoder = ce.BinaryEncoder(cols=['State', 'Crop','Season'])

# Perform the encoding
df_encoded = encoder.fit_transform(df2)

df_encoded
# Out:
#       Crop_0  Crop_1  Crop_2  Crop_3  Crop_4  Crop_5  Crop_Year  Season_0  \
# 0          0       0       0       0       0       1       1997         0
# 1          0       0       0       0       1       0       1997         0
# 2          0       0       0       0       1       1       1997         0
# 3          0       0       0       0       1       1       1997         0
# 4          0       0       0       1       0       0       1997         0
# ...      ...     ...     ...     ...     ...     ...        ...       ...
# 5110       0       0       1       1       1       1       2005         1
# 5111       0       1       1       0       0       0       2005         0
# 5112       0       1       1       0       0       1       2005         0
# 5113       0       1       0       0       0       0       2005         0
# 5114       1       0       1       0       0       0       2005         1
#
#       Season_1  Season_2  State_0  State_1  State_2      Area  Production  \
# 0            0         1        0        0        1   93100.0    133342.0
# 1            1         0        0        0        1  421810.0     98473.0
# 2            1         0        0        0        1  301149.0    132056.0
# 3            1         1        0        0        1     820.0       662.0
# 4            1         0        0        0        1    3825.0       924.0
# ...        ...       ...      ...      ...      ...       ...         ...
# 5110         1         0        0        1        1   12410.0     25326.0
# 5111         1         0        0        1        1     132.0        85.0
# 5112         1         0        0        1        1       1.0         1.0
# 5113         0         1        0        1        1    2099.0    299000.0
# 5114         0         0        0        1        1    1638.0       626.0
#
#       Annual_Rainfall   Fertilizer  Pesticide       Yield
# 0           1266.7000   8860327.00   28861.00    1.293571
# 1           1266.7000  40143657.70  130761.10    0.268235
# 2           1266.7000  28660350.33   93356.19    0.404545
# 3           1266.7000     78039.40     254.20    0.810000
# 4           1266.7000    364025.25    1185.75    0.437500
# ...               ...          ...        ...         ...
# 5110        1434.5875   1488207.20    2606.10    2.890000
# 5111        1434.5875     15829.44      27.72    0.356667
# 5112        1434.5875       119.92       0.21    1.000000
# 5113        1434.5875    251712.08     440.79  109.130000
# 5114        1434.5875    196428.96     343.98    0.633333
#
# [5067 rows x 19 columns]

# %%
corr = df_encoded.corr()
corr.style.background_gradient(cmap='PuOr_r').format(precision=3)
# Out:
# <style type="text/css">
# #T_22665_row0_col0, #T_22665_row1_col1, #T_22665_row2_col2, #T_22665_row3_col3, #T_22665_row4_col4, #T_22665_row5_col5, #T_22665_row6_col6, #T_22665_row7_col7, #T_22665_row8_col8, #T_22665_row9_col9, #T_22665_row10_col10, #T_22665_row11_col11, #T_22665_row12_col12, #T_22665_row13_col13, #T_22665_row14_col14, #T_22665_row15_col15, #T_22665_row16_col16, #T_22665_row17_col17, #T_22665_row18_col18 {
#   background-color: #7f3b08;
#   color: #f1f1f1;
# }
# #T_22665_row0_col1, #T_22665_row0_col3, #T_22665_row1_col0, #T_22665_row2_col14, #T_22665_row2_col18, #T_22665_row4_col14, #T_22665_row4_col18, #T_22665_row5_col14, #T_22665_row5_col18, #T_22665_row7_col8, #T_22665_row7_col9, #T_22665_row8_col7, #T_22665_row9_col2, #T_22665_row9_col4, #T_22665_row10_col11, #T_22665_row10_col12, #T_22665_row10_col15, #T_22665_row11_col13, #T_22665_row11_col16, #T_22665_row11_col17, #T_22665_row13_col6, #T_22665_row15_col10, #T_22665_row18_col5 {
#   background-color: #2d004b;
#   color: #f1f1f1;
# }
# #T_22665_row0_col2, #T_22665_row1_col6, #T_22665_row4_col6, #T_22665_row6_col14, #T_22665_row6_col17, #T_22665_row8_col5 {
#   background-color: #552889;
#   color: #f1f1f1;
# }
# #T_22665_row0_col4, #T_22665_row10_col14, #T_22665_row15_col13 {
#   background-color: #4a1d78;
#   color: #f1f1f1;
# }
# #T_22665_row0_col5, #T_22665_row1_col4, #T_22665_row7_col18 {
#   background-color: #3f1268;
#   color: #f1f1f1;
# }
# #T_22665_row0_col6, #T_22665_row5_col16, #T_22665_row15_col3, #T_22665_row15_col18 {
#   background-color: #6a4c9a;
#   color: #f1f1f1;
# }
# #T_22665_row0_col7 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_22665_row0_col8, #T_22665_row1_col8, #T_22665_row3_col12, #T_22665_row10_col8 {
#   background-color: #bfbbda;
#   color: #000000;
# }
# #T_22665_row0_col9, #T_22665_row3_col11, #T_22665_row6_col12, #T_22665_row8_col13, #T_22665_row18_col8 {
#   background-color: #a79fca;
#   color: #f1f1f1;
# }
# #T_22665_row0_col10, #T_22665_row6_col8, #T_22665_row11_col8 {
#   background-color: #cfcfe5;
#   color: #000000;
# }
# #T_22665_row0_col11, #T_22665_row3_col0, #T_22665_row3_col2, #T_22665_row7_col11, #T_22665_row13_col3, #T_22665_row16_col3, #T_22665_row16_col9, #T_22665_row17_col3, #T_22665_row18_col17 {
#   background-color: #8073ac;
#   color: #f1f1f1;
# }
# #T_22665_row0_col12, #T_22665_row5_col9, #T_22665_row9_col11, #T_22665_row10_col0, #T_22665_row14_col7 {
#   background-color: #b6b0d4;
#   color: #000000;
# }
# #T_22665_row0_col13, #T_22665_row10_col3 {
#   background-color: #390c5e;
#   color: #f1f1f1;
# }
# #T_22665_row0_col14, #T_22665_row2_col5 {
#   background-color: #3e1165;
#   color: #f1f1f1;
# }
# #T_22665_row0_col15, #T_22665_row7_col2, #T_22665_row14_col12 {
#   background-color: #b4aed3;
#   color: #000000;
# }
# #T_22665_row0_col16 {
#   background-color: #360959;
#   color: #f1f1f1;
# }
# #T_22665_row0_col17, #T_22665_row8_col18 {
#   background-color: #330655;
#   color: #f1f1f1;
# }
# #T_22665_row0_col18 {
#   background-color: #42156c;
#   color: #f1f1f1;
# }
# #T_22665_row1_col2, #T_22665_row5_col2 {
#   background-color: #6d529c;
#   color: #f1f1f1;
# }
# #T_22665_row1_col3, #T_22665_row14_col4, #T_22665_row15_col17 {
#   background-color: #44176f;
#   color: #f1f1f1;
# }
# #T_22665_row1_col5, #T_22665_row5_col17, #T_22665_row10_col9, #T_22665_row14_col2 {
#   background-color: #644395;
#   color: #f1f1f1;
# }
# #T_22665_row1_col7, #T_22665_row5_col10, #T_22665_row5_col12 {
#   background-color: #c2bedc;
#   color: #000000;
# }
# #T_22665_row1_col9, #T_22665_row1_col12, #T_22665_row2_col12, #T_22665_row2_col15, #T_22665_row7_col0 {
#   background-color: #b7b1d5;
#   color: #000000;
# }
# #T_22665_row1_col10, #T_22665_row2_col10, #T_22665_row4_col10 {
#   background-color: #c9c8e1;
#   color: #000000;
# }
# #T_22665_row1_col11, #T_22665_row7_col1, #T_22665_row8_col11, #T_22665_row13_col4, #T_22665_row15_col7, #T_22665_row16_col1, #T_22665_row17_col1 {
#   background-color: #9d94c2;
#   color: #f1f1f1;
# }
# #T_22665_row1_col13, #T_22665_row9_col5, #T_22665_row12_col13 {
#   background-color: #613d93;
#   color: #f1f1f1;
# }
# #T_22665_row1_col14, #T_22665_row9_col0, #T_22665_row13_col14, #T_22665_row16_col14, #T_22665_row17_col4 {
#   background-color: #9990bf;
#   color: #f1f1f1;
# }
# #T_22665_row1_col15 {
#   background-color: #c6c4df;
#   color: #000000;
# }
# #T_22665_row1_col16, #T_22665_row6_col16, #T_22665_row6_col18, #T_22665_row12_col18 {
#   background-color: #5f3a91;
#   color: #f1f1f1;
# }
# #T_22665_row1_col17, #T_22665_row6_col5, #T_22665_row11_col4, #T_22665_row12_col16 {
#   background-color: #5d3790;
#   color: #f1f1f1;
# }
# #T_22665_row1_col18, #T_22665_row3_col10, #T_22665_row11_col1 {
#   background-color: #b1aad1;
#   color: #000000;
# }
# #T_22665_row2_col0 {
#   background-color: #6f559e;
#   color: #f1f1f1;
# }
# #T_22665_row2_col1, #T_22665_row10_col16, #T_22665_row18_col16 {
#   background-color: #867ab0;
#   color: #f1f1f1;
# }
# #T_22665_row2_col3 {
#   background-color: #451871;
#   color: #f1f1f1;
# }
# #T_22665_row2_col4, #T_22665_row3_col6, #T_22665_row5_col6, #T_22665_row6_col3, #T_22665_row7_col3 {
#   background-color: #522584;
#   color: #f1f1f1;
# }
# #T_22665_row2_col6, #T_22665_row2_col9, #T_22665_row11_col5, #T_22665_row13_col11, #T_22665_row18_col6 {
#   background-color: #532687;
#   color: #f1f1f1;
# }
# #T_22665_row2_col7 {
#   background-color: #dfe1ee;
#   color: #000000;
# }
# #T_22665_row2_col8 {
#   background-color: #f8f4ee;
#   color: #000000;
# }
# #T_22665_row2_col11, #T_22665_row5_col4, #T_22665_row10_col17 {
#   background-color: #8477af;
#   color: #f1f1f1;
# }
# #T_22665_row2_col13, #T_22665_row8_col16, #T_22665_row8_col17, #T_22665_row12_col1, #T_22665_row18_col11 {
#   background-color: #a198c5;
#   color: #f1f1f1;
# }
# #T_22665_row2_col16, #T_22665_row3_col13, #T_22665_row4_col13, #T_22665_row13_col1, #T_22665_row16_col4 {
#   background-color: #9b92c1;
#   color: #f1f1f1;
# }
# #T_22665_row2_col17, #T_22665_row3_col1, #T_22665_row3_col16, #T_22665_row4_col16, #T_22665_row7_col15, #T_22665_row8_col0, #T_22665_row8_col1, #T_22665_row9_col14, #T_22665_row17_col14 {
#   background-color: #988dbe;
#   color: #f1f1f1;
# }
# #T_22665_row3_col4, #T_22665_row4_col5, #T_22665_row4_col9 {
#   background-color: #745ea2;
#   color: #f1f1f1;
# }
# #T_22665_row3_col5, #T_22665_row12_col4, #T_22665_row13_col0, #T_22665_row16_col0, #T_22665_row17_col0 {
#   background-color: #725ba1;
#   color: #f1f1f1;
# }
# #T_22665_row3_col7, #T_22665_row6_col11, #T_22665_row6_col15 {
#   background-color: #c8c6e0;
#   color: #000000;
# }
# #T_22665_row3_col8 {
#   background-color: #c5c2de;
#   color: #000000;
# }
# #T_22665_row3_col9, #T_22665_row11_col9 {
#   background-color: #cccbe3;
#   color: #000000;
# }
# #T_22665_row3_col14, #T_22665_row4_col0, #T_22665_row4_col11, #T_22665_row15_col14 {
#   background-color: #8275ad;
#   color: #f1f1f1;
# }
# #T_22665_row3_col15 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_22665_row3_col17, #T_22665_row3_col18, #T_22665_row4_col17, #T_22665_row10_col2, #T_22665_row11_col0 {
#   background-color: #9489bb;
#   color: #f1f1f1;
# }
# #T_22665_row4_col1, #T_22665_row7_col5, #T_22665_row9_col3 {
#   background-color: #7764a5;
#   color: #f1f1f1;
# }
# #T_22665_row4_col2, #T_22665_row6_col4 {
#   background-color: #70589f;
#   color: #f1f1f1;
# }
# #T_22665_row4_col3, #T_22665_row7_col13, #T_22665_row10_col5, #T_22665_row12_col3, #T_22665_row12_col17 {
#   background-color: #5a318d;
#   color: #f1f1f1;
# }
# #T_22665_row4_col7, #T_22665_row10_col7 {
#   background-color: #e4e5f0;
#   color: #000000;
# }
# #T_22665_row4_col8, #T_22665_row16_col8 {
#   background-color: #e7e8f1;
#   color: #000000;
# }
# #T_22665_row4_col12, #T_22665_row16_col7, #T_22665_row17_col7 {
#   background-color: #bdb9d9;
#   color: #000000;
# }
# #T_22665_row4_col15, #T_22665_row10_col1, #T_22665_row14_col8, #T_22665_row14_col13, #T_22665_row15_col8 {
#   background-color: #afa8d0;
#   color: #000000;
# }
# #T_22665_row5_col0, #T_22665_row12_col2, #T_22665_row18_col3, #T_22665_row18_col13 {
#   background-color: #887cb2;
#   color: #f1f1f1;
# }
# #T_22665_row5_col1, #T_22665_row9_col18, #T_22665_row14_col16 {
#   background-color: #ada6ce;
#   color: #f1f1f1;
# }
# #T_22665_row5_col3, #T_22665_row11_col3 {
#   background-color: #684998;
#   color: #f1f1f1;
# }
# #T_22665_row5_col7 {
#   background-color: #d

# %%
from sklearn.preprocessing import RobustScaler
# Columns to be scaled
columns_to_scale = ['Crop_Year', 'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Area', 'Production']

# Initialize the scaler
scaler = RobustScaler()

# Fit and transform the specified columns
df_encoded[columns_to_scale] = scaler.fit_transform(df_encoded[columns_to_scale])
df_encoded.head()
# Out:
#    Crop_0  Crop_1  Crop_2  Crop_3  Crop_4  Crop_5  Crop_Year  Season_0  \
# 0       0       0       0       0       0       1  -1.272727         0
# 1       0       0       0       0       1       0  -1.272727         0
# 2       0       0       0       0       1       1  -1.272727         0
# 3       0       0       0       0       1       1  -1.272727         0
# 4       0       0       0       1       0       0  -1.272727         0
#
#    Season_1  Season_2  State_0  State_1  State_2      Area  Production  \
# 0         0         1        0        0        1  0.677294    0.548297
# 1         1         0        0        0        1  3.633478    0.371199
# 2         1         0        0        0        1  2.548339    0.541765
# 3         1         1        0        0        1 -0.152607   -0.125577
# 4         1         0        0        0        1 -0.125582   -0.124246
#
#    Annual_Rainfall  Fertilizer  Pesticide     Yield
# 0         0.367125    0.421475   0.815467  1.293571
# 1         0.367125    2.488414   4.242163  0.268235
# 2         0.367125    1.729693   2.984311  0.404545
# 3         0.367125   -0.158785  -0.146523  0.810000
# 4         0.367125   -0.139889  -0.115196  0.437500
